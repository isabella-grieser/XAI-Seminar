# %%
# %load_ext autoreload
# %autoreload 2
from model import ExplainableModel
from sklearn.model_selection import train_test_split
from explanationplots import *
# Out:
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_clustering.py:35: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _pt_shuffle_rec(i, indexes, index_mask, partition_tree, M, pos):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_clustering.py:54: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def delta_minimization_order(all_masks, max_swap_size=100, num_passes=2):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_clustering.py:63: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _reverse_window(order, start, length):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_clustering.py:69: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _reverse_window_score_gain(masks, order, start, length):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_clustering.py:77: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _mask_delta_score(m1, m2):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\links.py:5: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def identity(x):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\links.py:10: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _identity_inverse(x):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\links.py:15: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def logit(x):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\links.py:20: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _logit_inverse(x):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_masked_model.py:363: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _build_fixed_single_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_masked_model.py:385: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _build_fixed_multi_output(averaged_outs, last_outs, outputs, batch_positions, varying_rows, num_varying_rows, link, linearizing_weights):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_masked_model.py:428: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _init_masks(cluster_matrix, M, indices_row_pos, indptr):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\utils\_masked_model.py:439: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _rec_fill_masks(cluster_matrix, indices_row_pos, indptr, indices, M, ind):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\maskers\_tabular.py:186: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _single_delta_mask(dind, masked_inputs, last_mask, data, x, noop_code):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\maskers\_tabular.py:197: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _delta_masking(masks, x, curr_delta_inds, varying_rows_out,
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\maskers\_image.py:175: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def _jit_build_partition_tree(xmin, xmax, ymin, ymax, zmin, zmax, total_ywidth, total_zwidth, M, clustering, q):
# C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\shap\explainers\_partition.py:676: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def lower_credit(i, value, M, values, clustering):
# The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.

# %%
def get_data():
    df = pd.read_csv("data/paysim.csv")
    df = df.drop("isFlaggedFraud", axis=1)

    df = df.drop(['nameOrig', 'nameDest'], axis=1)
    df = pd.get_dummies(df, columns=['type'])

    train, test = train_test_split(df, test_size=0.1, stratify=df["isFraud"])
    x_train, y_train = train.drop(['isFraud'], axis=1), train["isFraud"]
    x_test, y_test = test.drop(['isFraud'], axis=1), test["isFraud"]

    return x_train, y_train, x_test, y_test

# %%
x_train, y_train, x_test, y_test = get_data()

params = {"objective": "binary:logistic",
          "verbosity": 1,
          "tree_method": "gpu_hist"}

model = ExplainableModel(x_train, y_train, params=params,
                         path="./weights/model.pkl",
                         explainer_path="./weights/explainer.pkl",
                         seed=42)

# model.train(iterations=300, do_train=False, load=True, save=False)
y_hat = model.predict(x_test)

# %%
create_class_cluster(model)
# Out:
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# NameError: name 'NORM_PATHS_AND_BASE_CONTAINER' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# NameError: name 'NORM_PATHS_AND_BASE_CONTAINER' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# NameError: name 'NORM_PATHS_AND_BASE_CONTAINER' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# NameError: name 'NORM_PATHS_AND_BASE_CONTAINER' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# NameError: name 'NORM_PATHS_AND_BASE_CONTAINER' is not defined
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 230, in _NormPaths
#     return NORM_PATHS_CONTAINER[filename]
# KeyError: 'C:\\Users\\Isabe\\.julia\\conda\\3\\envs\\newxai\\lib\\ntpath.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 230, in _NormPaths
#     return NORM_PATHS_CONTAINER[filename]
# KeyError: 'C:\\Users\\Isabe\\.julia\\conda\\3\\envs\\newxai\\lib\\ntpath.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 230, in _NormPaths
#     return NORM_PATHS_CONTAINER[filename]
# KeyError: 'C:\\Users\\Isabe\\.julia\\conda\\3\\envs\\newxai\\lib\\ntpath.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 230, in _NormPaths
#     return NORM_PATHS_CONTAINER[filename]
# KeyError: 'C:\\Users\\Isabe\\.julia\\conda\\3\\envs\\newxai\\lib\\ntpath.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1548, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 586, in get_abs_path_real_path_and_base_from_frame
#     return NORM_PATHS_AND_BASE_CONTAINER[frame.f_code.co_filename]
# KeyError: 'C:\\Program Files\\JetBrains\\PyCharm 2022.3.1\\plugins\\python\\helpers\\pydev\\pydevd_file_utils.py'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 1550, in _pydevd_bundle.pydevd_cython_win32_39_64.ThreadTracer.__call__
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd_file_utils.py", line 593, in get_abs_path_real_path_and_base_from_frame
#     if get_abs_path_real_path_and_base_from_file is None:  # Interpreter shutdown
# NameError: name 'get_abs_path_real_path_and_base_from_file' is not defined
# [autoreload of pydevd failed: Traceback (most recent call last):
#   File "C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\IPython\extensions\autoreload.py", line 273, in check
#     superreload(m, reload, self.old_objects)
#   File "C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\IPython\extensions\autoreload.py", line 496, in superreload
#     update_generic(old_obj, new_obj)
#   File "C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\IPython\extensions\autoreload.py", line 393, in update_generic
#     update(a, b)
#   File "C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\IPython\extensions\autoreload.py", line 361, in update_class
#     update_instances(old, new)
#   File "C:\Users\Isabe\.julia\conda\3\envs\newxai\lib\site-packages\IPython\extensions\autoreload.py", line 319, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment: 'ThreadsSuspendedSingleNotification' object layout differs from 'ThreadsSuspendedSingleNotification'
# ]
# Traceback (most recent call last):
#   File "_pydevd_bundle\pydevd_cython_win32_39_64.pyx", line 914, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_plugin.py", line 242, in suspend
#     return suspend_jupyter(pydb, thread, frame)
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_plugin.py", line 191, in suspend_jupyter
#     pydb.set_suspend(thread, cmd)
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd.py", line 971, in set_suspend
#     self._threads_suspended_single_notification.increment_suspend_time()
#   File "C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd.py", line 275, in increment_suspend_time
#     with self._lock:
# TypeError: descriptor '_lock' for 'ThreadsSuspendedSingleNotification' objects doesn't apply to a 'ThreadsSuspendedSingleNotification' object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 # pydev_debug_cell
# ----> 2 create_class_cluster(model)
#
# Cell In[5], line 2
#       1 # pydev_debug_cell
# ----> 2 create_class_cluster(model)
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:1179, in _pydevd_bundle.pydevd_cython_win32_39_64.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:620, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:932, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\pydevd_cython_win32_39_64.pyx:914, in _pydevd_bundle.pydevd_cython_win32_39_64.PyDBFrame.trace_dispatch()
#
# File C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_plugin.py:242, in suspend(plugin, pydb, thread, frame, bp_type)
#     240 def suspend(plugin, pydb, thread, frame, bp_type):
#     241     if bp_type == 'jupyter-line' and _is_inside_jupyter_cell(frame, pydb):
# --> 242         return suspend_jupyter(pydb, thread, frame)
#     243     return None
#
# File C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers-pro\jupyter_debug\pydev_jupyter_plugin.py:191, in suspend_jupyter(pydb, thread, frame, cmd, message)
#     189 def suspend_jupyter(pydb, thread, frame, cmd=CMD_SET_BREAK, message=None):
#     190     frame = JupyterFrame(frame, pydb)
# --> 191     pydb.set_suspend(thread, cmd)
#     192     thread.additional_info.suspend_type = JUPYTER_SUSPEND
#     193     if cmd == CMD_ADD_EXCEPTION_BREAK:
#     194         # send exception name as message
#
# File C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd.py:971, in PyDB.set_suspend(self, thread, stop_reason, suspend_other_threads, is_pause)
#     955 def set_suspend(self, thread, stop_reason, suspend_other_threads=False, is_pause=False):
#     956     '''
#     957     :param thread:
#     958         The thread which should be suspended.
#    (...)
#     969         thread paused.
#     970     '''
# --> 971     self._threads_suspended_single_notification.increment_suspend_time()
#     972     if is_pause:
#     973         self._threads_suspended_single_notification.on_pause()
#
# File C:\Program Files\JetBrains\PyCharm 2022.3.1\plugins\python\helpers\pydev\pydevd.py:275, in AbstractSingleNotificationBehavior.increment_suspend_time(self)
#     274 def increment_suspend_time(self):
# --> 275     with self._lock:
#     276         self._suspend_time_request = self._next_request_time()
#
# TypeError: descriptor '_lock' for 'ThreadsSuspendedSingleNotification' objects doesn't apply to a 'ThreadsSuspendedSingleNotification' object
